# %% [markdown]
# # **Diabetes Risk Analysis**

# %% [markdown]
# ## Objectives
#
# - Download cardiovascular disease dataset (preprocessed) from kaggle
# - Load the dataset into a pandas dataframe
# - Perform basic data exploration
# - Create new features based on existing data for the analysis purpose
# - Prepare the dataset for calculating diabetes risk using ChatGPT
# - Reload the dataset with diabetes risk percentage
# - Visualize the data using matplotlib and seaborn
#
# ## Inputs
#
# - **Dataset:** `cardio_data_processed.csv`. The dataset is available on Kaggle at [Cardiovascular Disease](https://www.kaggle.com/datasets/colewelkins/cardiovascular-disease/data).
# - **Diabetes Risk Percentage:** With the help of ChatGPT, I will calculate the percentage of individuals at risk of diabetes based on the dataset on a separate notebook and merge the results with the main dataset.
# - **Python Version:** 3.12.8
# - **Python Libraries:** pandas, numpy, matplotlib, seaborn
# - **Environment:** Jupyter Notebook or any Python IDE that supports data analysis
# - **Columns of interest:**
#     - Target column: `diab_risk_cat` || `diab_risk_percent`
#     - Features: `weight`, `active`, `bmi_simp_cat`, `age_simp_group`, `gender`, `bp_category`
#
#
# ## Outputs
#
# - **Cleaned dataset:** `cardio_data_with_diabetes_risk_clean.csv` is stored in the `data/cleaned` folder.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/raihannasir/Documents/DA_AI/diabetes_risk/diabetes_risk/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/raihannasir/Documents/DA_AI/diabetes_risk/diabetes_risk'

# %% [markdown]
# ---

# %% [markdown]
# # Import necessary libraries and Packages
#
# **I will import the necessary libraries and packages including pandas, numpy, matplotlib, and seaborn, which will be used for data analysis and visualization purposes.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Importing necessary libraries
from sklearn.pipeline import Pipeline
from feature_engine.outliers import Winsorizer
from feature_engine import transformation as vt

# %% [markdown]
# ## Load the raw dataset

# %%
raw_path = 'dataset/raw/cardio_data_processed.csv'

# %%
df = pd.read_csv(raw_path)
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio  age_years        bmi           bp_category  \
# 0     0       1       0         50  21.967120  Hypertension Stage 1
# 1     0       1       1         55  34.927679  Hypertension Stage 2
# 2     0       0       1         51  23.507805  Hypertension Stage 1
# 3     0       1       1         48  28.710479  Hypertension Stage 2
# 4     0       0       0         47  23.011177                Normal
#
#     bp_category_encoded
# 0  Hypertension Stage 1
# 1  Hypertension Stage 2
# 2  Hypertension Stage 1
# 3  Hypertension Stage 2
# 4                Normal

# %% [markdown]
# **Using `.info()` method, I will try to explore general information about the structure of the dataset, including the number of entries, column names, data types, non-null counts. This will help identify any missing values or inconsistencies in the dataset.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68205 entries, 0 to 68204
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   68205 non-null  int64
#  1   age                  68205 non-null  int64
#  2   gender               68205 non-null  int64
#  3   height               68205 non-null  int64
#  4   weight               68205 non-null  float64
#  5   ap_hi                68205 non-null  int64
#  6   ap_lo                68205 non-null  int64
#  7   cholesterol          68205 non-null  int64
#  8   gluc                 68205 non-null  int64
#  9   smoke                68205 non-null  int64
#  10  alco                 68205 non-null  int64
#  11  active               68205 non-null  int64
#  12  cardio               68205 non-null  int64
#  13  age_years            68205 non-null  int64
#  14  bmi                  68205 non-null  float64
#  15  bp_category          68205 non-null  object
#  16  bp_category_encoded  68205 non-null  object
# dtypes: float64(2), int64(13), object(2)
# memory usage: 8.8+ MB

# %% [markdown]
# ## Initial data screening and exploration:
#
# **Use describe() to summarize the dataset of numerical features.**
# - Check for missing values, outliers, and basic statistics like mean, median, and standard deviation.

# %%
df.describe().T
# Out:
#                count          mean           std           min           25%  \
# id           68205.0  49972.410498  28852.138290      0.000000  24991.000000
# age          68205.0  19462.667737   2468.381854  10798.000000  17656.000000
# gender       68205.0      1.348625      0.476539      1.000000      1.000000
# height       68205.0    164.372861      8.176756     55.000000    159.000000
# weight       68205.0     74.100688     14.288862     11.000000     65.000000
# ap_hi        68205.0    126.434924     15.961685     90.000000    120.000000
# ap_lo        68205.0     81.263925      9.143985     60.000000     80.000000
# cholesterol  68205.0      1.363243      0.678080      1.000000      1.000000
# gluc         68205.0      1.225174      0.571288      1.000000      1.000000
# smoke        68205.0      0.087662      0.282805      0.000000      0.000000
# alco         68205.0      0.053134      0.224302      0.000000      0.000000
# active       68205.0      0.803548      0.397317      0.000000      1.000000
# cardio       68205.0      0.493688      0.499964      0.000000      0.000000
# age_years    68205.0     52.823635      6.769909     29.000000     48.000000
# bmi          68205.0     27.510513      6.026497      3.471784     23.875115
#
#                       50%           75%           max
# id           50008.000000  74878.000000  99999.000000
# age          19700.000000  21323.000000  23713.000000
# gender           1.000000      2.000000      2.000000
# height         165.000000    170.000000    250.000000
# weight          72.000000     82.000000    200.000000
# ap_hi          120.000000    140.000000    180.000000
# ap_lo           80.000000     90.000000    120.000000
# cholesterol      1.000000      1.000000      3.000000
# gluc             1.000000      1.000000      3.000000
# smoke            0.000000      0.000000      1.000000
# alco             0.000000      0.000000      1.000000
# active           1.000000      1.000000      1.000000
# cardio           0.000000      1.000000      1.000000
# age_years       53.000000     58.000000     64.000000
# bmi             26.346494     30.116213    298.666667

# %% [markdown]
# **Use describe(include='object') to summarize the dataset of categorical features.**
# - Check for number of unique values, the most frequent value and number of times it appears.

# %%
df.describe(include='object').T
# Out:
#                      count unique                   top   freq
# bp_category          68205      4  Hypertension Stage 1  39750
# bp_category_encoded  68205      4  Hypertension Stage 1  39750

# %% [markdown]
# ## Drop some of the unnecessary columns from the raw dataset as they are not needed.
#  - **ID:** Unique identifier for each individual, not needed for analysis.
#  - **age:** Age is already represented in years under `'age_years'` column.
#  - **bp_category_encoded:** This is the repetitive column of `bp_category` and it is not encoded. So, I will drop this column.

# %%
df.drop(columns= ['id', 'age', 'bp_category_encoded'], inplace=True)
df.head()
# Out:
#    gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0       2     168    62.0    110     80            1     1      0     0
# 1       1     156    85.0    140     90            3     1      0     0
# 2       1     165    64.0    130     70            3     1      0     0
# 3       2     169    82.0    150    100            1     1      0     0
# 4       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio  age_years        bmi           bp_category
# 0       1       0         50  21.967120  Hypertension Stage 1
# 1       1       1         55  34.927679  Hypertension Stage 2
# 2       0       1         51  23.507805  Hypertension Stage 1
# 3       1       1         48  28.710479  Hypertension Stage 2
# 4       0       0         47  23.011177                Normal

# %% [markdown]
# **After dropping the unnecessary columns, I will check the followings:**
# - the shape of the dataset after dropping the unnecessary columns.
# - name of the columns in the dataset.
# - presence of any missing values per column in the dataset.

# %%
print(df.shape)
print(df.columns)
print(df.isnull().sum())
# Out:
# (68205, 14)
# Index(['gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc',
#        'smoke', 'alco', 'active', 'cardio', 'age_years', 'bmi', 'bp_category'],
#       dtype='object')
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# age_years      0
# bmi            0
# bp_category    0
# dtype: int64

# %% [markdown]
# **I will rename the `age_years` column to `age` for consistency with the original dataset.**

# %%
df.rename(columns = {'age_years': 'age',}, inplace=True)
df.head()
# Out:
#    gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0       2     168    62.0    110     80            1     1      0     0
# 1       1     156    85.0    140     90            3     1      0     0
# 2       1     165    64.0    130     70            3     1      0     0
# 3       2     169    82.0    150    100            1     1      0     0
# 4       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio  age        bmi           bp_category
# 0       1       0   50  21.967120  Hypertension Stage 1
# 1       1       1   55  34.927679  Hypertension Stage 2
# 2       0       1   51  23.507805  Hypertension Stage 1
# 3       1       1   48  28.710479  Hypertension Stage 2
# 4       0       0   47  23.011177                Normal

# %% [markdown]
# **For the purpose of analysis convenience, I will create two new categorical columns using functions:**
# - `age_group`: Categorizing individuals into age groups.
# - `bmi_category`: Categorizing individuals into BMI groups.
#
# **These columns will be used during the dashboard creation to visualize the data more effectively.**

# %%
# Function to categorize age into groups

def age_group(age):
    if age < 30:
        return '18-29'
    elif age < 40:
        return '30-39'
    elif age < 50:
        return '40-49'
    elif age < 60:
        return '50-59'
    elif age >= 60:
        return '60+'

# Function to categorize BMI into groups
def bmi_category(bmi):
    if bmi < 18:
        return 'Underweight'
    elif 18 <= bmi < 25:
        return 'Normal weight'
    elif 25 <= bmi < 30:
        return 'Overweight'
    elif 30 <= bmi < 35:
        return 'Obesity I'
    elif 35 <= bmi < 40:
        return 'Obesity II'
    else:
        return 'Obesity III'

df = df.pipe(
    lambda x: x.assign(
        age_group=x['age'].apply(age_group),
        bmi_category=x['bmi'].apply(bmi_category)
    )
)

df.head()
# Out:
#    gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0       2     168    62.0    110     80            1     1      0     0
# 1       1     156    85.0    140     90            3     1      0     0
# 2       1     165    64.0    130     70            3     1      0     0
# 3       2     169    82.0    150    100            1     1      0     0
# 4       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio  age        bmi           bp_category age_group  \
# 0       1       0   50  21.967120  Hypertension Stage 1     50-59
# 1       1       1   55  34.927679  Hypertension Stage 2     50-59
# 2       0       1   51  23.507805  Hypertension Stage 1     50-59
# 3       1       1   48  28.710479  Hypertension Stage 2     40-49
# 4       0       0   47  23.011177                Normal     40-49
#
#     bmi_category
# 0  Normal weight
# 1      Obesity I
# 2  Normal weight
# 3     Overweight
# 4  Normal weight

# %% [markdown]
# **I will further simplify the `age_group` and `bmi_category` columns for better readability and Hypothesis testing purposes**

# %%
def simplify_age_group(group):
    if group in ['18-29', '30-39']:
        return 'Adult'
    elif group in ['40-49', '50-59']:
        return 'Middle-aged'
    else:
        return 'Senior'

def simplify_bmi_category(category):
    if category in ['Underweight', 'Normal weight']:
        return 'Low BMI'
    elif category in ['Overweight', 'Obesity I']:
        return 'Mid BMI'
    else:
        return 'High BMI'

df = df.pipe(
    lambda x: x.assign(
        age_simp_group=x['age_group'].apply(simplify_age_group),
        bmi_simp_cat=x['bmi_category'].apply(simplify_bmi_category)
    )
)

df.head()
# Out:
#    gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0       2     168    62.0    110     80            1     1      0     0
# 1       1     156    85.0    140     90            3     1      0     0
# 2       1     165    64.0    130     70            3     1      0     0
# 3       2     169    82.0    150    100            1     1      0     0
# 4       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio  age        bmi           bp_category age_group  \
# 0       1       0   50  21.967120  Hypertension Stage 1     50-59
# 1       1       1   55  34.927679  Hypertension Stage 2     50-59
# 2       0       1   51  23.507805  Hypertension Stage 1     50-59
# 3       1       1   48  28.710479  Hypertension Stage 2     40-49
# 4       0       0   47  23.011177                Normal     40-49
#
#     bmi_category age_simp_group bmi_simp_cat
# 0  Normal weight    Middle-aged      Low BMI
# 1      Obesity I    Middle-aged      Mid BMI
# 2  Normal weight    Middle-aged      Low BMI
# 3     Overweight    Middle-aged      Mid BMI
# 4  Normal weight    Middle-aged      Low BMI

# %% [markdown]
# **Since cardovascular disease dataset has some key features that are relevant for diabetes risk analysis but not present in the dataset and my focus is to understand diabetes risk factors, I will create a new column called `diabetes_risk_percentage` with the help of ChatGPT to store the calculated diabetes risk percentage for each individual.**

# %% [markdown]
# **Save the cleaned dataset in cleaned folder as a new CSV file for the purpose of Diabetes Risk Percentage calculation with the help of ChatGPT**

# %%
df.to_csv('dataset/cleaned/cardio_data_processed_clean.csv', index=False)

# %% [markdown]
# **Load the cleaned dataset with diabetes risk percentage.**

# %%
df_diab = pd.read_csv('dataset/raw/cardio_data_with_diabetes_risk.csv')
print(df_diab.shape)
print(df_diab.info())
print(df_diab.isnull().sum())
df_diab.head()
# Out:
# (68205, 19)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68205 entries, 0 to 68204
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             68205 non-null  int64
#  1   height             68205 non-null  int64
#  2   weight             68205 non-null  float64
#  3   ap_hi              68205 non-null  int64
#  4   ap_lo              68205 non-null  int64
#  5   cholesterol        68205 non-null  int64
#  6   gluc               68205 non-null  int64
#  7   smoke              68205 non-null  int64
#  8   alco               68205 non-null  int64
#  9   active             68205 non-null  int64
#  10  cardio             68205 non-null  int64
#  11  age                68205 non-null  int64
#  12  bmi                68205 non-null  float64
#  13  bp_category        68205 non-null  object
#  14  age_group          68205 non-null  object
#  15  bmi_category       68205 non-null  object
#  16  age_simp_group     68205 non-null  object
#  17  bmi_simp_cat       68205 non-null  object
#  18  diab_risk_percent  68205 non-null  float64
# dtypes: float64(3), int64(11), object(5)
# memory usage: 9.9+ MB
# None
# gender               0
# height               0
# weight               0
# ap_hi                0
# ap_lo                0
# cholesterol          0
# gluc                 0
# smoke                0
# alco                 0
# active               0
# cardio               0
# age                  0
# bmi                  0
# bp_category          0
# age_group            0
# bmi_category         0
# age_simp_group       0
# bmi_simp_cat         0
# diab_risk_percent    0
# dtype: int64
#    gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0       2     168    62.0    110     80            1     1      0     0
# 1       1     156    85.0    140     90            3     1      0     0
# 2       1     165    64.0    130     70            3     1      0     0
# 3       2     169    82.0    150    100            1     1      0     0
# 4       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio  age        bmi           bp_category age_group  \
# 0       1       0   50  21.967120  Hypertension Stage 1     50-59
# 1       1       1   55  34.927679  Hypertension Stage 2     50-59
# 2       0       1   51  23.507805  Hypertension Stage 1     50-59
# 3       1       1   48  28.710479  Hypertension Stage 2     40-49
# 4       0       0   47  23.011177                Normal     40-49
#
#   bmi_category age_simp_group bmi_simp_cat  diab_risk_percent
# 0       Normal    Middle-aged      Low BMI              16.15
# 1      Obese I    Middle-aged      Mid BMI              57.50
# 2       Normal    Middle-aged      Low BMI              18.21
# 3   Overweight    Middle-aged      Mid BMI              19.62
# 4       Normal    Middle-aged      Low BMI               9.76

# %% [markdown]
# **As the dataset has 68205 rows, there might be a possibility of duplicate rows. Existence of duplicate rows can impact the analysis. Therefore, I will check the existence of duplicate rows in the dataset.**

# %%
print(df_diab.duplicated().sum())
df_diab[df_diab.duplicated()]
# Out:
# 9
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 4319        2     165    65.0    120     80            1     1      0     0
# 12371       1     165    65.0    120     80            1     1      0     0
# 19242       1     160    58.0    120     80            1     1      0     0
# 26274       1     158    58.0    110     70            1     1      0     0
# 32212       2     162    56.0    120     80            1     1      0     0
# 42185       1     165    65.0    120     80            1     1      0     0
# 51056       1     161    68.0    120     80            1     1      0     0
# 57682       1     170    70.0    120     80            1     1      0     0
# 65927       1     170    70.0    120     80            1     1      0     0
#
#        active  cardio  age        bmi           bp_category age_group  \
# 4319        1       0   57  23.875115  Hypertension Stage 1     50-59
# 12371       1       0   53  23.875115  Hypertension Stage 1     50-59
# 19242       1       0   53  22.656250  Hypertension Stage 1     50-59
# 26274       1       0   39  23.233456                Normal     30-39
# 32212       1       1   53  21.338211  Hypertension Stage 1     50-59
# 42185       1       0   55  23.875115  Hypertension Stage 1     50-59
# 51056       1       0   50  26.233556  Hypertension Stage 1     50-59
# 57682       1       0   43  24.221453  Hypertension Stage 1     40-49
# 65927       1       0   50  24.221453  Hypertension Stage 1     50-59
#
#       bmi_category age_simp_group bmi_simp_cat  diab_risk_percent
# 4319        Normal    Middle-aged      Low BMI              15.95
# 12371       Normal    Middle-aged      Low BMI              15.64
# 19242       Normal    Middle-aged      Low BMI              15.08
# 26274       Normal          Adult      Low BMI               5.47
# 32212       Normal    Middle-aged      Low BMI              14.51
# 42185       Normal    Middle-aged      Low BMI              16.03
# 51056   Overweight    Middle-aged      Mid BMI              32.71
# 57682       Normal    Middle-aged      Low BMI              10.33
# 65927       Normal    Middle-aged      Low BMI              18.60

# %% [markdown]
# **As I can see here, there are 16 duplicate rows in the dataset. However, after having a closer look at the duplicate dataset, I can see that these duplicate rows are not identical. Specifically, `bmi`, `age` and `diab_risk_percent` are different. Therefore, I will keep them in the dataset for further analysis.**

# %% [markdown]
# ## Diabetes Risk Category
#
# **Create Diabetes Risk Category based on the `diabetes_risk_percentage` column, which will be used for hypothesis testing and visualization purposes.**

# %%
def diab_risk(percent):
    if percent < 20:
        return 'Low Risk'
    elif 20 <= percent < 50:
        return 'Moderate Risk'
    elif percent >= 50:
        return 'High Risk'
    
df_diab['diab_risk_cat'] = df_diab['diab_risk_percent'].apply(diab_risk)
df_diab.head()
# Out:
#    gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0       2     168    62.0    110     80            1     1      0     0
# 1       1     156    85.0    140     90            3     1      0     0
# 2       1     165    64.0    130     70            3     1      0     0
# 3       2     169    82.0    150    100            1     1      0     0
# 4       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio  age        bmi           bp_category age_group  \
# 0       1       0   50  21.967120  Hypertension Stage 1     50-59
# 1       1       1   55  34.927679  Hypertension Stage 2     50-59
# 2       0       1   51  23.507805  Hypertension Stage 1     50-59
# 3       1       1   48  28.710479  Hypertension Stage 2     40-49
# 4       0       0   47  23.011177                Normal     40-49
#
#   bmi_category age_simp_group bmi_simp_cat  diab_risk_percent diab_risk_cat
# 0       Normal    Middle-aged      Low BMI              16.15      Low Risk
# 1      Obese I    Middle-aged      Mid BMI              57.50     High Risk
# 2       Normal    Middle-aged      Low BMI              18.21      Low Risk
# 3   Overweight    Middle-aged      Mid BMI              19.62      Low Risk
# 4       Normal    Middle-aged      Low BMI               9.76      Low Risk

# %% [markdown]
# **Get a quick glance on the total frequency of each category in each column of the dataset using `value_counts()` method.**

# %%
for col in df_diab.select_dtypes(include=['object']).columns:
    print(f"Total number of occurrences of '{col}' column:\n")
    print(df_diab[col].value_counts())
    print("\n")
# Out:
# Total number of occurrences of 'bp_category' column:
#
# bp_category
# Hypertension Stage 1    39750
# Hypertension Stage 2    15937
# Normal                   9417
# Elevated                 3101
# Name: count, dtype: int64
#
#
# Total number of occurrences of 'age_group' column:
#
# age_group
# 50-59    34596
# 40-49    19173
# 60+      12683
# 30-39     1750
# 18-29        3
# Name: count, dtype: int64
#
#
# Total number of occurrences of 'bmi_category' column:
#
# bmi_category
# Normal         25174
# Overweight     24591
# Obese I        11852
# Obese II        4179
# Obese III       1778
# Underweight      631
# Name: count, dtype: int64
#
#
# Total number of occurrences of 'age_simp_group' column:
#
# age_simp_group
# Middle-aged    53769
# Senior         12683
# Adult           1753
# Name: count, dtype: int64
#
#
# Total number of occurrences of 'bmi_simp_cat' column:
#
# bmi_simp_cat
# Mid BMI     36443
# Low BMI     25805
# High BMI     5957
# Name: count, dtype: int64
#
#
# Total number of occurrences of 'diab_risk_cat' column:
#
# diab_risk_cat
# Moderate Risk    30979
# Low Risk         24632
# High Risk        12594
# Name: count, dtype: int64

# %% [markdown]
# **Encode `age_group`, `bmi_category`, `bp_category`, and `diab_risk_cat` for the ease of further analysis**

# %%
encodings = {
    'age_group': {
        '18-29': 0, '30-39': 1, '40-49': 2, '50-59': 3, '60+': 4
    },
    'bmi_category': {
        'Underweight': 0, 'Normal': 1, 'Overweight': 2,
        'Obese I': 3, 'Obese II': 4, 'Obese III': 5
    },
    'bp_category': {
        'Normal': 0, 'Elevated': 1,
        'Hypertension Stage 1': 2, 'Hypertension Stage 2': 3
    },
    'diab_risk_cat': {
        'Low Risk': 0, 'Moderate Risk': 1, 'High Risk': 2
    }
}

# Apply mappings to the DataFrame to create numerical columns
for col, val in encodings.items():
    df_diab[f'{col}_num'] = df_diab[col].map(val)

# %%
df_diab.head()
# Out:
#    gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0       2     168    62.0    110     80            1     1      0     0
# 1       1     156    85.0    140     90            3     1      0     0
# 2       1     165    64.0    130     70            3     1      0     0
# 3       2     169    82.0    150    100            1     1      0     0
# 4       1     156    56.0    100     60            1     1      0     0
#
#    active  ...  age_group  bmi_category  age_simp_group bmi_simp_cat  \
# 0       1  ...      50-59        Normal     Middle-aged      Low BMI
# 1       1  ...      50-59       Obese I     Middle-aged      Mid BMI
# 2       0  ...      50-59        Normal     Middle-aged      Low BMI
# 3       1  ...      40-49    Overweight     Middle-aged      Mid BMI
# 4       0  ...      40-49        Normal     Middle-aged      Low BMI
#
#   diab_risk_percent diab_risk_cat age_group_num bmi_category_num  \
# 0             16.15      Low Risk             3                1
# 1             57.50     High Risk             3                3
# 2             18.21      Low Risk             3                1
# 3             19.62      Low Risk             2                2
# 4              9.76      Low Risk             2                1
#
#    bp_category_num diab_risk_cat_num
# 0                2                 0
# 1                3                 2
# 2                2                 0
# 3                3                 0
# 4                0                 0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Skewness and Kurtosis

# %% [markdown]
# ***Skewness – Asymmetry of the Distribution***
#
# **Definition:** Skewness measures the asymmetry of the probability distribution of a real-valued random variable.
#
# **Types:**
# - Zero skewness: Data is symmetrically distributed (like a normal distribution).
# - Positive skew: Tail on the right side is longer or fatter; mean > median.
# - Negative skew: Tail on the left side is longer or fatter; mean < median.
#
#
# ***Kurtosis – Tailedness of the Distribution***
#
# **Definition:** Kurtosis measures the "tailedness" or the extremity of outliers in the data.
#
# **Types:**
# - Mesokurtic (kurtosis ≈ 3): Normal distribution.
# - Leptokurtic (kurtosis > 3): Heavy tails; more outliers.
# - Platykurtic (kurtosis < 3): Light tails; fewer outliers.

# %% [markdown]
# **I will focus certain numerical columns from the dataset for skewness and kurtosis analysis, which will help in understanding the distribution of the data and identifying potential outliers.**

# %%
num_cols = df_diab[['gender', 'weight', 'active', 'bmi']]

output = []
for col in num_cols.columns:
    skew = num_cols[col].skew()
    kurt = num_cols[col].kurtosis()
    output.append({
        'Column': col,
        'Skewness': skew,
        'Kurtosis': kurt
    })
output_df = pd.DataFrame(output)
output_df
# Out:
#    Column  Skewness    Kurtosis
# 0  gender  0.635327   -1.596406
# 1  weight  1.005810    2.557139
# 2  active -1.528034    0.334898
# 3     bmi  7.818718  230.590500

# %% [markdown]
# Based on the skewness and kurtosis values, I can determine the following:
#
# | Feature                  | Skewness | Kurtosis | Interpretation                                                                                             |
# | ------------------------ | -------- | -------- | ---------------------------------------------------------------------------------------------------------- |
# | **gender**               | 0.64     | -1.60    | Slight right skew; light tails → fairly balanced but fewer extremes.                                       |
# | **weight**               | 1.01     | 2.56     | Right-skewed; moderate tail → many lighter individuals, some heavy outliers.                               |
# | **active**               | -1.53    | 0.33     | Left-skewed; light tails → more active people, few very inactive.                                          |
# | **bmi**                  | 7.82     | 230.59   | **Extremely** right-skewed; **very high kurtosis** → majority with normal BMI, some extreme obesity cases. |
#
# The `weight` column has a moderate right skewness and kurtosis, indicating that while most individuals have a weight around the mean, there are some heavier outliers. Hence, I will apply **log transformation** to the `weight` column to reduce skewness and make the distribution more normal.
#
# The `active` column shows a left skewness and light tails, indicating that most individuals are active, with fewer very inactive individuals. Since, the data in this column in bionary format (0 or 1), I will not apply any transformation to this column.
#
# The `bmi` column shows an extremely high skewness and kurtosis, indicating a significant number of individuals with normal BMI and some extreme cases of obesity. Therefore, I will apply **Winsorization** to the `bmi` column to limit the impact of extreme values and make the distribution more normal.
#
# ***LogTransformation*** is a technique used to reduce skewness in data by applying a logarithmic function to the values. It is particularly useful for right-skewed data, where a few extreme values can disproportionately affect the mean and variance.
#
# ***Winsorization*** is a statistical technique used to limit the impact of extreme values (outliers) in a dataset by replacing them with less extreme values. It is particularly useful for reducing the influence of outliers on statistical analyses.

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# **Applying LogTransformer and Winsorizer transformations to the `weight` and `bmi` columns respectively for the purpose of reducing skewness and making the distributions more normal.**

# %%
pipe = Pipeline([
    ('right_skewed', vt.LogTransformer(variables=['weight'])),
    ('handle_outliers', Winsorizer(
        capping_method='gaussian',
        tail='both',
        fold=1.5,
        variables=['bmi'])
    )
])

df_trans = pipe.fit_transform(df_diab)
df_trans.head()
# Out:
#    gender  height    weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0       2     168  4.127134    110     80            1     1      0     0
# 1       1     156  4.442651    140     90            3     1      0     0
# 2       1     165  4.158883    130     70            3     1      0     0
# 3       2     169  4.406719    150    100            1     1      0     0
# 4       1     156  4.025352    100     60            1     1      0     0
#
#    active  ...  age_group  bmi_category  age_simp_group bmi_simp_cat  \
# 0       1  ...      50-59        Normal     Middle-aged      Low BMI
# 1       1  ...      50-59       Obese I     Middle-aged      Mid BMI
# 2       0  ...      50-59        Normal     Middle-aged      Low BMI
# 3       1  ...      40-49    Overweight     Middle-aged      Mid BMI
# 4       0  ...      40-49        Normal     Middle-aged      Low BMI
#
#   diab_risk_percent diab_risk_cat age_group_num bmi_category_num  \
# 0             16.15      Low Risk             3                1
# 1             57.50     High Risk             3                3
# 2             18.21      Low Risk             3                1
# 3             19.62      Low Risk             2                2
# 4              9.76      Low Risk             2                1
#
#    bp_category_num diab_risk_cat_num
# 0                2                 0
# 1                3                 2
# 2                2                 0
# 3                3                 0
# 4                0                 0
#
# [5 rows x 24 columns]

# %% [markdown]
# **After applying the transformations, I will check the skewness and kurtosis of the `weight` and `bmi` columns again to confirm that the transformations have effectively reduced skewness and made the distributions more normal.**

# %%
num_cols = df_trans[['gender', 'weight', 'active', 'bmi']]

output = []
for col in num_cols.columns:
    skew = num_cols[col].skew()
    kurt = num_cols[col].kurtosis()
    output.append({
        'Column': col,
        'Skewness': skew,
        'Kurtosis': kurt
    })
output_df = pd.DataFrame(output)
output_df
# Out:
#    Column  Skewness  Kurtosis
# 0  gender  0.635327 -1.596406
# 1  weight  0.219132  0.789084
# 2  active -1.528034  0.334898
# 3     bmi  0.500621 -0.534195

# %% [markdown]
# Output of the skewness and kurtosis after applying the transformations:
#
# | Column     | Skewness | Kurtosis | Interpretation                                                                                                             |
# | ---------- | -------- | -------- | -------------------------------------------------------------------------------------------------------------------------- |
# | **weight** | 0.22     | 0.79     | Slight right skew; nearly normal with mild tail weight. Distribution is fairly symmetric with a few heavier outliers.      |
# | **bmi**    | 0.50     | -0.53    | Mild right skew; light tails. BMI is somewhat concentrated around central values, with slightly more high values than low. |
#
# Now, both `weight` and `bmi` columns have reduced skewness and kurtosis, indicating that the transformations have effectively normalized the distributions.

# %% [markdown]
# ## General Correlation Analysis
# **I will use the `.corr()` method to calculate the correlation matrix of the dataset, which will help identify relationships between different features.**
# **I will visualize the correlation matrix using a heatmap to better understand the relationships between features.**

# %%
df_trans.select_dtypes(exclude=['object']).corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ed606_row0_col0, #T_ed606_row1_col1, #T_ed606_row2_col2, #T_ed606_row3_col3, #T_ed606_row4_col4, #T_ed606_row5_col5, #T_ed606_row6_col6, #T_ed606_row7_col7, #T_ed606_row8_col8, #T_ed606_row9_col9, #T_ed606_row10_col10, #T_ed606_row11_col11, #T_ed606_row12_col12, #T_ed606_row13_col13, #T_ed606_row14_col14, #T_ed606_row15_col15, #T_ed606_row16_col16, #T_ed606_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ed606_row0_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_ed606_row0_col2, #T_ed606_row8_col17 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_ed606_row0_col3, #T_ed606_row1_col16, #T_ed606_row3_col8, #T_ed606_row7_col9, #T_ed606_row8_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ed606_row0_col4, #T_ed606_row5_col7, #T_ed606_row12_col0, #T_ed606_row15_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_ed606_row0_col5, #T_ed606_row7_col6, #T_ed606_row9_col6 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ed606_row0_col6, #T_ed606_row1_col5, #T_ed606_row1_col6, #T_ed606_row1_col11, #T_ed606_row1_col12, #T_ed606_row1_col13, #T_ed606_row1_col14, #T_ed606_row1_col15, #T_ed606_row1_col17, #T_ed606_row9_col2, #T_ed606_row9_col3, #T_ed606_row9_col4, #T_ed606_row9_col10, #T_ed606_row9_col16, #T_ed606_row10_col9, #T_ed606_row11_col8, #T_ed606_row13_col0, #T_ed606_row13_col1, #T_ed606_row13_col7, #T_ed606_row14_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ed606_row0_col7, #T_ed606_row8_col7 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_ed606_row0_col8, #T_ed606_row5_col3, #T_ed606_row5_col14, #T_ed606_row8_col13, #T_ed606_row9_col1, #T_ed606_row11_col5 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_ed606_row0_col9, #T_ed606_row0_col10, #T_ed606_row8_col14, #T_ed606_row12_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_ed606_row0_col11, #T_ed606_row9_col8, #T_ed606_row16_col8 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_ed606_row0_col12, #T_ed606_row0_col16, #T_ed606_row8_col5, #T_ed606_row16_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_ed606_row0_col13, #T_ed606_row6_col7, #T_ed606_row7_col5, #T_ed606_row9_col5, #T_ed606_row9_col14 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_ed606_row0_col14, #T_ed606_row0_col17, #T_ed606_row8_col11, #T_ed606_row12_col8, #T_ed606_row15_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ed606_row0_col15, #T_ed606_row3_col7, #T_ed606_row4_col7, #T_ed606_row7_col2, #T_ed606_row8_col2, #T_ed606_row9_col7 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_ed606_row1_col0 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_ed606_row1_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_ed606_row1_col3, #T_ed606_row7_col10, #T_ed606_row10_col8, #T_ed606_row13_col9, #T_ed606_row17_col1 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_ed606_row1_col4, #T_ed606_row3_col9, #T_ed606_row4_col9, #T_ed606_row6_col8, #T_ed606_row8_col4, #T_ed606_row15_col1, #T_ed606_row15_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_ed606_row1_col7 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_ed606_row1_col8, #T_ed606_row2_col6, #T_ed606_row2_col7, #T_ed606_row5_col0, #T_ed606_row6_col10 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_ed606_row1_col9, #T_ed606_row6_col9, #T_ed606_row7_col3, #T_ed606_row7_col14, #T_ed606_row8_col6, #T_ed606_row8_col10, #T_ed606_row8_col16, #T_ed606_row12_col7, #T_ed606_row16_col9 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_ed606_row1_col10, #T_ed606_row7_col4, #T_ed606_row7_col16, #T_ed606_row11_col9, #T_ed606_row12_col9, #T_ed606_row13_col8, #T_ed606_row14_col9, #T_ed606_row15_col9, #T_ed606_row17_col8, #T_ed606_row17_col9 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_ed606_row2_col0, #T_ed606_row10_col11 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_ed606_row2_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_ed606_row2_col3, #T_ed606_row3_col11, #T_ed606_row12_col3 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_ed606_row2_col4, #T_ed606_row13_col10, #T_ed606_row15_col3, #T_ed606_row16_col2 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_ed606_row2_col5, #T_ed606_row12_col11, #T_ed606_row14_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_ed606_row2_col8, #T_ed606_row6_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_ed606_row2_col9, #T_ed606_row11_col7, #T_ed606_row14_col7, #T_ed606_row17_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_ed606_row2_col10, #T_ed606_row3_col0, #T_ed606_row15_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_ed606_row2_col11 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_ed606_row2_col12 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_ed606_row2_col13 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_ed606_row2_col14 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_ed606_row2_col15 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_ed606_row2_col16, #T_ed606_row5_col10, #T_ed606_row16_col11 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_ed606_row2_col17 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_ed606_row3_col1, #T_ed606_row12_col5, #T_ed606_row16_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ed606_row3_col2 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_ed606_row3_col4, #T_ed606_row3_col16, #T_ed606_row4_col3 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_ed606_row3_col5, #T_ed606_row4_col1, #T_ed606_row13_col16 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_ed606_row3_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_ed606_row3_col10 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_ed606_row3_col12 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_ed606_row3_col13 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_ed606_row3_col14, #T_ed606_row12_col4, #T_ed606_row13_col4, #T_ed606_row13_col5, #T_ed606_row14_col12, #T_ed606_row16_col1, #T_ed606_row17_col10 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_ed606_row3_col15, #T_ed606_row10_col13, #T_ed606_row16_col13 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_ed606_row3_col17, #T_ed606_row4_col13, #T_ed606_row17_col14 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_ed606_row4_col0, #T_ed606_row11_col3, #T_ed606_row15_col10, #T_ed606_row17_col16 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_ed606_row4_col2, #T_ed606_row6_col12, #T_ed606_row6_col15, #T_ed606_row10_col14, #T_ed606_row11_col10 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_ed606_row4_col5, #T_ed606_row4_col14 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_ed606_row4_col6, #T_ed606_row16_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_ed606_row4_col8, #T_ed606_row5_col8, #T_ed606_row9_col11, #T_ed606_row14_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_ed606_row4_col10, #T_ed606_row5_col13, #T_ed606_row16_col10 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_ed606_row4_col11, #T_ed606_row5_col11 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_ed606_row4_col12 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_ed606_row4_col15 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_ed606_row4_col16, #T_ed606_row16_col4 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_ed606_row4_col17 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_ed606_row5_col1, #T_ed606_row5_col4, #T_ed606_row9_col0, #T_ed606_row9_col15, #T_ed606_row10_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_ed606_row5_col2, #T_ed606_row6_col14, #T_ed606_row7_col13, #T_ed606_row7_col15 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_ed606_row5_col6, #T_ed606_row11_col17 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_ed606_row5_col9, #T_ed606_row10_col7 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_ed606_row5_col12, #T_ed606_row5_col15 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_ed606_row5_col16, #T_

# %% [markdown]
# Considering the target `diab_risk_percent` column, the correlation matrix shows good correlation accross the feature columns except for `active` column, which has a very low correlation with the target column. Though this indicates that the level of physical activity does not have a significant impact on diabetes risk in this dataset, it seems counterintuitive as physical activity is generally considered a key factor in diabetes risk. This could be due to the nature of the dataset or other confounding factors not captured in the data.
#
# Therefore, I will perform a **`AB test`** to check the significance of the difference in diabetes risk percentage between active and inactive individuals. This will help determine if there is a statistically significant difference in diabetes risk based on physical activity levels.

# %% [markdown]
# **Saving the final cleaned dataset with the transformations applied and the diabetes risk percentage calculated as a new CSV file in the cleaned folder.**

# %%
df_trans.to_csv('dataset/cleaned/cardio_data_with_diabetes_risk_clean.csv', index=False)
